# %% [markdown]
# This is practice number 1 after completion of linear_regression_single-variable tutorial
# Here I need to predict the price in the year 2020.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn import linear_model
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3156\890684115.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df= pd.read_csv('Datasets/canada_per_capita_income.csv')
df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
#%matplotlib inline
plt.scatter(df.year,df['per capita income (US$)'], color='green',marker='+')
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# e:\Projects\Machine_Learning_tutorial\venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18602.90731472])

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])
